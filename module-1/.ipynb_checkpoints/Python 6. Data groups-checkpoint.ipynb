# %%
import pandas as pd

df = pd.read_csv('data_sf.csv')
display(df)
# Out:
#        Unnamed: 0                Name  Age Nationality                 Club  \
# 0               0            L. Messi   31   Argentina         FC Barcelona
# 1               1   Cristiano Ronaldo   33    Portugal             Juventus
# 2               2           Neymar Jr   26      Brazil  Paris Saint-Germain
# 3               3              De Gea   27       Spain    Manchester United
# 4               4        K. De Bruyne   27     Belgium      Manchester City
# ...           ...                 ...  ...         ...                  ...
# 12892       13121        J. Lundstram   19     England      Crewe Alexandra
# 12893       13122  N. Christoffersson   19      Sweden       Trelleborgs FF
# 12894       13123           B. Worman   16     England     Cambridge United
# 12895       13124      D. Walker-Rice   17     England      Tranmere Rovers
# 12896       13125           G. Nugent   16     England      Tranmere Rovers
#
# ...

# %%
small_df = df[df.columns[0:7]].head(25)

s = small_df['Nationality'].value_counts()
s_df = s.reset_index()
s_df.columns = ['Nationality','Players Count']
display(s_df)
# Out:
#    Nationality  Players Count
# 0        Spain              4
# 1      Uruguay              3
# 2      Belgium              3
# 3      Germany              3
# 4    Argentina              3
# 5       France              2
# 6        Italy              1
# 7     Portugal              1
# 8       Brazil              1
# 9      England              1
# 10     Croatia              1
# 11      Poland              1
# 12    Slovenia              1

# %%
df[(df.Nationality == 'Spain')].Wage.value_counts(bins=4, normalize=True).reset_index()
# Out:
#                   index      Wage
# 0    (620.999, 95750.0]  0.970194
# 1   (95750.0, 190500.0]  0.016393
# 2  (190500.0, 285250.0]  0.008942
# 3  (285250.0, 380000.0]  0.004471

# %%
df[(df.Age>35)].Club.value_counts()
display(df[(df.Age>35)].Club.value_counts().reset_index())
# Out:
#                           index  Club
# 0    Hokkaido Consadole Sapporo     4
# 1         Club Atlético Huracán     4
# 2        Club Atlético Talleres     3
# 3                     Benevento     3
# 4           Club Atlético Tigre     3
# ..                          ...   ...
# 207         Paris Saint-Germain     1
# 208     Athletic Club de Bilbao     1
# 209                  Real Betis     1
# 210                 Santa Clara     1
# 211                    Sassuolo     1
#
# [212 rows x 2 columns]

# %%
df[(df.Nationality == 'Spain')].Age.value_counts(normalize=True).reset_index()
# Out:
#     index       Age
# 0      21  0.117735
# 1      22  0.095380
# 2      20  0.077496
# 3      23  0.071535
# 4      25  0.064083
# 5      27  0.062593
# 6      24  0.059613
# 7      28  0.053651
# 8      26  0.053651
# 9      29  0.047690
# 10     19  0.047690
# 11     18  0.038748
# 12     30  0.038748
# 13     31  0.032787
# 14     32  0.032787
# 15     33  0.031297
# 16     34  0.022355
# 17     17  0.013413
# 18     35  0.011923
# 19     36  0.010432
# 20     37  0.008942
# 21     39  0.002981
# 22     16  0.002981
# 23     38  0.001490

# %%
groups_df = df.groupby(['Position'])['Wage'].sum().sort_values(ascending=False)
print(groups_df >5000000)
# Out:
# Position
# ST      True
# GK      True
# CB      True
# CM      True
# LB      True
# CAM     True
# LM      True
# RM      True
# RB      True
# CDM    False
# RCB    False
# LCB    False
# RW     False
# RCM    False
# LCM    False
# LW     False
# LS     False
# RDM    False
# RS     False
# LDM    False
# RF     False
# LF     False
# RWB    False
# LAM    False
# LWB    False
# CF     False
# RAM    False
# Name: Wage, dtype: bool

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean()
# Out:
#                      Wage        Age  ShotPower
# Nationality
# Afghanistan   1250.000000  22.500000  53.750000
# Albania       5931.034483  23.689655  54.551724
# Algeria      15810.810811  27.027027  56.567568
# Andorra       1000.000000  28.000000  58.000000
# Angola        7100.000000  24.700000  63.700000
# ...                   ...        ...        ...
# Uzbekistan    9000.000000  29.500000  71.500000
# Venezuela     6611.111111  23.638889  57.222222
# Wales         9529.411765  24.754902  48.558824
# Zambia        2833.333333  21.833333  66.833333
# Zimbabwe      5000.000000  26.555556  62.888889
#
# [156 rows x 3 columns]

# %%
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean().sort_values(['Wage'],ascending=False).head(10)
df.loc[df['Nationality'] == 'Dominican Republic'][['Name','Club','Wage','Age','ShotPower']]
# Out:
#             Name         Club    Wage  Age  ShotPower
# 291      Mariano  Real Madrid  140000   24         85
# 6279  L. Quezada   Córdoba CF    2000   22         66

# %%
df.groupby(['Position'])[['Value']].mean().sort_values(['Value'], ascending=False).head(1)
# Out:
#                Value
# Position
# LF        27362500.0

# %%
df.groupby(['Club'])['Balance'].min().reset_index().head(10)
# Out:
#                     Club  Balance
# 0    SSV Jahn Regensburg       29
# 1  1. FC Heidenheim 1846       22
# 2   1. FC Kaiserslautern       29
# 3             1. FC Köln       31
# 4        1. FC Magdeburg       19
# 5         1. FC Nürnberg       44
# 6     1. FC Union Berlin       24
# 7        1. FSV Mainz 05       39
# 8             AC Ajaccio       54
# 9             AC Horsens       35

# %%
df_interim = df.groupby(['Club'])['Wage'].agg(['mean', 'median'])
df_interim[df_interim['mean'] == df_interim['median']]
# Out:
#                            mean  median
# Club
# 1. FC Magdeburg          4000.0    4000
# AEK Athens               1000.0    1000
# AJ Auxerre               2000.0    2000
# Benevento                2000.0    2000
# Bohemian FC              1000.0    1000
# Boyacá Chicó FC          1000.0    1000
# Bray Wanderers           1000.0    1000
# Brøndby IF               6000.0    6000
# CD Feirense              4000.0    4000
# CD Tondela               2000.0    2000
# Cork City                1000.0    1000
# Cruzeiro                13000.0   13000
# Deportivo Pasto          1000.0    1000
# Dinamo Zagreb            1000.0    1000
# Dundalk                  1000.0    1000
# Dynamo Kyiv              1000.0    1000
# Envigado FC              1000.0    1000
# FC Energie Cottbus       1000.0    1000
# FC Metz                  1500.0    1500
# Grimsby Town             2000.0    2000
# Göztepe SK               7000.0    7000
# HJK Helsinki             1000.0    1000
# ...

# %%
df = pd.read_csv('data_sf.csv')

newdf = df.groupby(['Club'])['Wage'].sum()
print(newdf.loc['Chelsea'])
# Out:
# 2035000

# %%
print(df[(df.Nationality == 'Argentina')&(df.Club == 'FC Barcelona')].Strength.max(),
      df[(df.Nationality == 'Argentina')&(df.Club == 'FC Barcelona')].Balance.max(),
      sep=";");'[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[[74]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]]'
# Out:
# 59;95

# %%
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Name'],
index=['Nationality'],
columns=['Club'],
aggfunc='count',
fill_value=0)

pivot.loc['Argentina']['Name']['Manchester United']
# Out:
# 2

# %%
df = pd.read_csv('data_sf.csv')

pivot = df.pivot_table(values=['Name'],
index=['Position'],
columns=['Club'],
aggfunc='count',
fill_value=0)

display(pivot.loc['CM'].value_counts())
# Out:
# 1    211
# 2    149
# 0    136
# 3     89
# 4     39
# 5     21
# 6      5
# Name: CM, dtype: int64

# %%
df = pd.read_csv('data_sf.csv')

pivot = df.pivot_table(values=['SprintSpeed'],
index = ['Position'],
columns = ['Club'],
aggfunc = 'mean')

task = ['Sydney FC', 'CD Lugo', 'Arsenal', 'Toronto FC', 'Girona FC', 'Melbourne Victory', 'Vitória']
result = {}

for item in task:
    result[pivot.loc['ST']['SprintSpeed'][item]] = item
    
print(result)
# Out:
# {88.0: 'Sydney FC', 87.0: 'CD Lugo', 83.0: 'Arsenal', 81.75: 'Toronto FC', nan: 'Girona FC', 81.0: 'Melbourne Victory', 91.0: 'Vitória'}
